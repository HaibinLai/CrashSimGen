# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: 读取CSV文件
data = pd.read_csv('attention_origin.csv')

# Step 2: 提取步骤（Step）和损失值（Value）
steps = data['Step']
values = data['Value']

# Step 3: 绘制训练损失图
plt.figure(figsize=(10, 6))  # 设置图形大小
plt.plot(steps, values, marker=',', linestyle='-', color='b', label='Training Loss')

# 添加标题和标签
plt.title('Training Loss vs Iteration Step')
plt.xlabel('Step')
plt.ylabel('Loss Value')

plt.yscale('log')

# 显示图例
plt.legend()

# 显示网格
plt.grid(True)

# 显示图形
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: 读取CSV文件
data = pd.read_csv('DDIM_fine_tune.csv')

# Step 2: 提取步骤（Step）和损失值（Value）
steps = data['Step']
values = data['Value']

# Step 3: 绘制训练损失图
plt.figure(figsize=(10, 6))  # 设置图形大小
plt.plot(steps, values, marker=',', linestyle='-', color='b', label='Training Loss')

# 添加标题和标签
plt.title('Training Loss vs Iteration Step')
plt.xlabel('Step')
plt.ylabel('Loss Value')

plt.yscale('log')

# 显示图例
plt.legend()

# 显示网格
plt.grid(True)

# 显示图形
plt.show()

# %%
# Step 1: 读取CSV文件
data2 = pd.read_csv('attention_origin.csv')

# Step 2: 提取步骤（Step）和损失值（Value）
steps2 = data2['Step']
values2 = data2['Value']

# Step 3: 绘制训练损失图
plt.figure(figsize=(10, 6))  # 设置图形大小
plt.plot(steps2, values2, marker=',', linestyle='-', color='b', label='Training Loss on original model')

plt.plot(steps, values, marker=',', linestyle='-', color='r', label='Training Loss with attention')

# 添加标题和标签
plt.title('Training Loss vs Iteration Step')
plt.xlabel('Step')
plt.ylabel('Loss Value')

# plt.yscale('log')

# 显示图例
plt.legend()

# 显示网格
plt.grid(True)

# 显示图形
plt.show()

# %%
# Step 1: 读取CSV文件
data3 = pd.read_csv('oscillation_dropping/DDPM_ori.csv')
data3 = pd.read_csv('DDPM_origin.csv')

data3 = data3[0:80]

# Step 2: 提取步骤（Step）和损失值（Value）
steps3 = data3['Step']
values3 = data3['Value']

# Step 3: 绘制训练损失图
plt.figure(figsize=(7.5,4.5))  # 设置图形大小
plt.plot(steps3, values3, marker=',', linestyle='-', color='b', label='Training Loss on DDPM Scheduler')

plt.plot(steps2, values2, marker=',', linestyle='-', color='r', label='Training Loss on DDIM Scheduler')

# plt.ylabel('Clocks($\mu S$)', fontdict={'family' : 'Times New Roman', 'size'   : 16})
# plt.xlabel('Time', fontdict={'family' : 'Times New Roman', 'size'   : 16})
# plt.bar_label('Training Loss on DDPM Scheduler', fontdict={'family' : 'Times New Roman', 'size'   : 16})

# 添加标题和标签
plt.title('Training Loss vs Iteration Step')
plt.xlabel('Step')
plt.ylabel('Loss Value')

# plt.yscale('log')

# 显示图例
plt.legend()

# 显示网格
plt.grid(True)
plt.savefig('DDIM.png')
# 显示图形
plt.show()

# %%
#  above are installed properly.
# model parameters: 56574595
# dataset: 62401
# model parameters: 63151235
