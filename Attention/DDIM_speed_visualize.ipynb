# %%
import matplotlib.pyplot as plt
import numpy as np

# 假设的数据
models = ['DDPM', 'DDIM']

# 训练时长（以分钟为单位）
time_minutes = [2*60 + 46, 49]  # DDPM 的时间是 2小时46分钟，DDIM 的时间是 49分钟

# 最终损失值
final_loss = [0.005230026
, 0.002600512
]  #  DDPM , DDIM 

# 设置位置
x = np.arange(len(models))

# 创建图形
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# 绘制训练时长条形图
ax1.bar(x, time_minutes, color=['blue', 'red'])
ax1.set_title('Comparison: Training Time for each epoch in average')
ax1.set_ylabel('Time (Minutes)')
ax1.set_xticks(x)
ax1.set_xticklabels(models)
ax1.set_ylim(0, max(time_minutes) + 30)  # 给y轴留一点空间

# 绘制最终损失值条形图
ax2.bar(x, final_loss, color=['blue', 'red'])
ax2.set_title('Comparison: Final Loss at ')
ax2.set_ylabel('Final Loss Value')
ax2.set_xticks(x)
ax2.set_xticklabels(models)
ax2.set_ylim(0, max(final_loss) + 0.001)  # 给y轴留一点空间

# 显示图形
plt.tight_layout()
plt.savefig('comparison_on_time.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.colors import BoundaryNorm
import ast

palette = sns.color_palette('Set2')
# palette = sns.color_palette('colorblind')
# sns.set(style='white', palette="Set2", color_codes=False)
sns.set(style='white', palette="Set2", color_codes=False)
sns.set_style("ticks")

# 假设的数据
models = ['DDPM without Attention','Attention with DDPM', 'Attention with DDIM']

# 训练时长（以分钟为单位）
time_minutes = [52.1 , 90.1 , 60.6]  # DDPM 的时间是 89分钟，DDIM 的时间是 49分钟

# 最终损失值
final_loss = [
    0.012378881
    ,
    0.00327464


, 0.002600512
]  #  DDPM , DDIM 

# 设置位置
x = np.arange(len(models))

# 创建图形
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# 绘制训练时长条形图
bars1 = ax1.bar(x, time_minutes,)
ax1.set_title('Training Time Comparison')
ax1.set_ylabel('Time (Minutes)')
ax1.set_xticks(x)
ax1.set_xticklabels(models)
ax1.set_ylim(0, max(time_minutes) + 30)  # 给y轴留一点空间

# 在训练时长条形图上添加数字标签
for i, bar in enumerate(bars1):
    ax1.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 2,  # x, y 坐标
             f'{bar.get_height():.1f}',  # 显示数字，保留1位小数
             ha='center', va='bottom', fontsize=12)
    
color=['orange','blue', 'red']

# 绘制最终损失值条形图
bars2 = ax2.bar(x, final_loss, )
ax2.set_title('Final Loss Comparison on step 4500')
ax2.set_ylabel('Final Loss Value')
ax2.set_xticks(x)
ax2.set_xticklabels(models)
ax2.set_ylim(0, max(final_loss) + 0.001)  # 给y轴留一点空间

# 在最终损失值条形图上添加数字标签
for i, bar in enumerate(bars2):
    ax2.text(bar.get_x() + bar.get_width() / 2, bar.get_height() ,  # x, y 坐标
             f'{bar.get_height():.6f}',  # 显示数字，
             ha='center', va='bottom', fontsize=12)

# 显示图形
plt.tight_layout()
plt.savefig('comparison_on_time.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# 假设的数据
models = ['DDPM without Attention', 'Attention with DDPM', 'Attention with DDIM']

# 训练时长（以分钟为单位）
time_minutes = [52.1, 90.1, 60.6]

# 最终损失值
final_loss = [0.012378881, 0.00327464, 0.002600512]

# 设置位置
x = np.arange(len(models))

# 创建图形
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# 使用seaborn调色板
palette = sns.color_palette("Set2", len(models))

# 绘制训练时长条形图
bars1 = ax1.bar(x, time_minutes, color=palette)
ax1.set_title('Training Time Comparison')
ax1.set_ylabel('Time (Minutes)')
ax1.set_xticks(x)
ax1.set_xticklabels(models)
ax1.set_ylim(0, max(time_minutes) + 30)  # 给y轴留一点空间

# 在训练时长条形图上添加数字标签
for i, bar in enumerate(bars1):
    ax1.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 2,  # x, y 坐标
             f'{bar.get_height():.1f}',  # 显示数字，保留1位小数
             ha='center', va='bottom', fontsize=12)

# 绘制最终损失值条形图
bars2 = ax2.bar(x, final_loss, color=palette)
ax2.set_title('Final Loss Comparison on step 4500')
ax2.set_ylabel('Final Loss Value')
ax2.set_xticks(x)
ax2.set_xticklabels(models)
ax2.set_ylim(0, max(final_loss) + 0.001)  # 给y轴留一点空间

# 在最终损失值条形图上添加数字标签
for i, bar in enumerate(bars2):
    ax2.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),  # x, y 坐标
             f'{bar.get_height():.6f}',  # 显示数字
             ha='center', va='bottom', fontsize=12)

# 设置Seaborn样式
sns.set(style="whitegrid")

# 显示图形
plt.tight_layout()
plt.savefig('comparison_on_time_seaborn.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# 假设的数据
models = ['DDPM \n without Attention', 'DDPM \n with Attention', 'DDIM \n with Attention']

# 训练时长（以分钟为单位）
time_minutes = [52.1, 90.1, 60.6]

# 最终损失值
final_loss = [0.012378881, 0.00327464, 0.002600512]

# 设置位置
x = np.arange(len(models))

# 创建图形
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# 使用seaborn调色板
palette = sns.color_palette("Set2", len(models))

# 强调"Attention with DDIM"的颜色
highlight_color = 'red'  # 你可以选择其他显眼的颜色
colors = [palette[0], palette[1], highlight_color]

# 绘制训练时长条形图
bars1 = ax1.bar(x, time_minutes, color=colors)
ax1.set_title('Average Training Time on each Epoch Comparison')
ax1.set_ylabel('Time (Minutes)')
ax1.set_xticks(x)
ax1.set_xticklabels(models)
ax1.set_ylim(0, max(time_minutes) + 10)  # 给y轴留一点空间

# 在训练时长条形图上添加数字标签
for i, bar in enumerate(bars1):
    ax1.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 2,  # x, y 坐标
             f'{bar.get_height():.1f}',  # 显示数字，保留1位小数
             ha='center', va='bottom', fontsize=12)

# 绘制最终损失值条形图
bars2 = ax2.bar(x, final_loss, color=colors)
ax2.set_title('Final Loss Comparison on step 4500')
ax2.set_ylabel('Final Loss Value')
ax2.set_xticks(x)
ax2.set_xticklabels(models)
ax2.set_ylim(0, max(final_loss) + 0.001)  # 给y轴留一点空间

# 在最终损失值条形图上添加数字标签
for i, bar in enumerate(bars2):
    ax2.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),  # x, y 坐标
             f'{bar.get_height():.6f}',  # 显示数字
             ha='center', va='bottom', fontsize=12)

# 设置Seaborn样式
sns.set(style="whitegrid")

# # 为"Attention with DDIM"添加注释
# ax2.annotate('Attention with DDIM', 
#              xy=(2, final_loss[2]), 
#              xytext=(2.2, final_loss[2] + 0.001),
#              arrowprops=dict(facecolor='black', arrowstyle="->"),
#              fontsize=12, color='red')

# 显示图形
plt.tight_layout()
plt.savefig('comparison_on_time_highlighted2.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# 损失值数据
losses = [0.007229907438158989, 0.005876998417079449]
models = ['Origin Model', 'fine-tuned Model']

# 设置位置
x = np.arange(len(models))

# 创建图形
fig, ax = plt.subplots(figsize=(6, 6))

# 使用seaborn的调色板
sns.set(style="whitegrid")  # 设置背景为网格样式
palette = sns.color_palette("Set2", 2)  # 使用Seaborn的调色板，选择两种颜色

# 绘制条形图
bars = ax.bar(x, losses, color=palette)

# 设置标题和标签
ax.set_title('Loss Comparison Between Origin and fine-tuned Models', fontsize=14)
ax.set_ylabel('Loss Value', fontsize=12)
ax.set_xticks(x)
ax.set_xticklabels(models, fontsize=12)
ax.set_ylim(0.004, 0.008)  # 设置y轴范围

# 在条形图上添加数字标签
for i, bar in enumerate(bars):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.00005,  # x, y 坐标
            f'{bar.get_height():.6f}',  # 显示数字，保留6位小数
            ha='center', va='bottom', fontsize=12)

plt.savefig('comparison_on_loss.png')

# 显示图形
plt.tight_layout()
plt.show()
